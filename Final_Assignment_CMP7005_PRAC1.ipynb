# %% [markdown]
# <a href="https://colab.research.google.com/github/jamalamro25/CMP7005_PRAC1_Jamalamro/blob/main/Final_Assignment_CMP7005_PRAC1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Part 1 - Data Hanlding

# %% [markdown]
# 1.1 Import data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/Programming for Data Analysis/Assigment/Assessment Data-20251028'
# Out:
# /content/drive/MyDrive/Programming for Data Analysis/Assigment/Assessment Data-20251028

# %%
# %ls
# Out:
# Ahmedabad_data.csv     Coimbatore_data.csv  Kolkata_data.csv
# Aizawl_data.csv        Delhi_data.csv       Lucknow_data.csv
# Amaravati_data.csv     Ernakulam_data.csv   Mumbai_data.csv
# Amritsar_data.csv      Gurugram_data.csv    Patna_data.csv
# Bengaluru_data.csv     Guwahati_data.csv    Shillong_data.csv
# Bhopal_data.csv        Hyderabad_data.csv   Talcher_data.csv
# Brajrajnagar_data.csv  Jaipur_data.csv      Thiruvananthapuram_data.csv
# Chandigarh_data.csv    Jorapokhar_data.csv  Visakhapatnam_data.csv
# Chennai_data.csv       Kochi_data.csv

# %% [markdown]
# 1.2 import Python libraries

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1.3 combine the csv files into one dataset

# %%
drive_path = '/content/drive/MyDrive/Programming for Data Analysis/Assigment/Assessment Data-20251028'
out_dir = '/content/drive/MyDrive/Programming for Data Analysis/Assigment/processed'

# %%
dataframes = []
for filename in os.listdir(drive_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(drive_path, filename)
        df_temp = pd.read_csv(os.path.join(drive_path, filename))
        dataframes.append(df_temp)

# %%
df = pd.concat(dataframes, ignore_index=True)

# %%
print("Merged data shape:", df.shape)
# Out:
# Merged data shape: (29531, 16)

# %% [markdown]
# 1.4 Understanding the dataset

# %%
df.shape
# Out:
# (29531, 16)

# %%
df.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# std       25.684275      6.962884     18.133775     21.694928     15.811136
# min        0.010000      0.000000      0.010000      0.010000      0.000000
# 25%        8.580000      0.510000      5.670000     18.860000      0.120000
# 50%       15.850000      0.890000      9.160000     30.840000      1.070000
# 75%       30.020000      1.450000     15.220000     45.570000      3.080000
# max      352.890000    175.810000    193.860000    257.730000    455.030000
#
#             Toluene        Xylene           AQI
# count  21490.000000  11422.000000  24850.000000
# mean       8.700972      3.070128    166.463581
# std       19.969164      6.323247    140.696585
# min        0.000000      0.000000     13.000000
# 25%        0.600000      0.140000     81.000000
# 50%        2.970000      0.980000    118.000000
# 75%        9.150000      3.350000    208.000000
# max      454.850000    170.370000   2049.000000

# %%
df.head()
# Out:
#       City        Date  PM2.5  PM10    NO    NO2   NOx  NH3     CO     SO2  \
# 0  Lucknow  01/01/2015    NaN   NaN  2.11  13.46  4.57  NaN  12.15  169.57
# 1  Lucknow  02/01/2015    NaN   NaN  2.37  10.76  3.80  NaN  14.00  169.46
# 2  Lucknow  03/01/2015    NaN   NaN  2.27  12.43  4.22  NaN  12.78  169.77
# 3  Lucknow  04/01/2015    NaN   NaN  2.24  12.46  4.22  NaN  11.85  169.56
# 4  Lucknow  05/01/2015    NaN   NaN  2.32  12.27  4.22  NaN  13.34  169.48
#
#       O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  25.92     1.35     3.93     NaN  NaN        NaN
# 1  21.66     1.97     5.74     NaN  NaN        NaN
# 2  22.40     1.83     4.76     NaN  NaN        NaN
# 3  21.41     2.27     4.77     NaN  NaN        NaN
# 4  20.60     2.49     4.78     NaN  NaN        NaN

# %%
df.tail()
# Out:
#            City        Date  PM2.5    PM10     NO    NO2    NOx    NH3    CO  \
# 29526  Amritsar  27/06/2020  51.10     NaN  25.25  20.80  35.75  14.07  0.66
# 29527  Amritsar  28/06/2020  45.24   40.00  23.11  17.90  27.47  13.25  0.63
# 29528  Amritsar  29/06/2020  26.77   60.69  26.99  19.83  34.03  14.94  0.67
# 29529  Amritsar  30/06/2020  41.64   76.49  22.03  15.97  30.60  13.29  0.69
# 29530  Amritsar  01/07/2020  57.67  100.99  32.81  15.11  30.20  17.73  0.59
#
#         SO2     O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 29526  4.55  16.48     1.30     1.10    8.82  74.0  Satisfactory
# 29527  5.22  16.48     1.16     0.98    7.85  85.0  Satisfactory
# 29528  4.89  16.48     1.30     1.10    8.81  49.0          Good
# 29529  4.67  16.48     1.30     1.10    8.72  66.0  Satisfactory
# 29530  3.48  16.48     1.30     1.10    8.82  78.0  Satisfactory

# %%
df.dtypes
# Out:
# City           object
# Date           object
# PM2.5         float64
# PM10          float64
# NO            float64
# NO2           float64
# NOx           float64
# NH3           float64
# CO            float64
# SO2           float64
# O3            float64
# Benzene       float64
# Toluene       float64
# Xylene        float64
# AQI           float64
# AQI_Bucket     object
# dtype: object

# %%
df.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 1.5 Data Cleaning

# %%
df.shape
# Out:
# (29531, 16)

# %%
df.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Xylene        18109
# PM10          11140
# NH3           10328
# Toluene        8041
# Benzene        5623
# AQI            4681
# AQI_Bucket     4681
# PM2.5          4598
# NOx            4185
# O3             4022
# SO2            3854
# NO2            3585
# NO             3582
# CO             2059
# Date              0
# City              0
# dtype: int64

# %%
df.dtypes
# Out:
# City           object
# Date           object
# PM2.5         float64
# PM10          float64
# NO            float64
# NO2           float64
# NOx           float64
# NH3           float64
# CO            float64
# SO2           float64
# O3            float64
# Benzene       float64
# Toluene       float64
# Xylene        float64
# AQI           float64
# AQI_Bucket     object
# dtype: object

# %%
def missing_value_table(df):
        mis_val = df.isnull().sum()
        mis_val_per = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_per], axis=1)
        mis_val_table = mis_val_table.rename(columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        mis_val_table = mis_val_table[mis_val_table.iloc[:,1] != 0].sort_values('% of Total Values', ascending=False)
        return mis_val_table
missing_values = missing_value_table(df)
display(missing_values.style.background_gradient(cmap='Reds'))
# Out:
# <style type="text/css">
# #T_fdff1_row0_col0, #T_fdff1_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_fdff1_row1_col0, #T_fdff1_row1_col1 {
#   background-color: #f5523a;
#   color: #f1f1f1;
# }
# #T_fdff1_row2_col0, #T_fdff1_row2_col1 {
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_fdff1_row3_col0, #T_fdff1_row3_col1 {
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_fdff1_row4_col0, #T_fdff1_row4_col1 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_fdff1_row5_col0, #T_fdff1_row5_col1, #T_fdff1_row6_col0, #T_fdff1_row6_col1 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_fdff1_row7_col0, #T_fdff1_row7_col1 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_fdff1_row8_col0, #T_fdff1_row8_col1 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_fdff1_row9_col0, #T_fdff1_row9_col1 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_fdff1_row10_col0, #T_fdff1_row10_col1 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_fdff1_row11_col0, #T_fdff1_row11_col1, #T_fdff1_row12_col0, #T_fdff1_row12_col1 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_fdff1_row13_col0, #T_fdff1_row13_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_fdff1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fdff1_level0_col0" class="col_heading level0 col0" >Missing Values</th>
#       <th id="T_fdff1_level0_col1" class="col_heading level0 col1" >% of Total Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fdff1_level0_row0" class="row_heading level0 row0" >Xylene</th>
#       <td id="T_fdff1_row0_col0" class="data row0 col0" >18109</td>
#       <td id="T_fdff1_row0_col1" class="data row0 col1" >61.322001</td>
#     </tr>
#     <tr>
#       <th id="T_fdff1_level0_row1" class="row_heading level0 row1" >PM10</th>
#       <td id="T_fdff1_row1_col0" class="data row1 col0" >11140</td>
#       <td id="T_fdff1_row1_col1" class="data row1 col1" >37.723071</td>
#     </tr>
#     <tr>
#       <th id="T_fdff1_level0_row2" class="row_heading level0 row2" >NH3</th>
#       <td id="T_fdff1_row2_col0" class="data row2 col0" >10328</td>
#       <td id="T_fdff1_row2_col1" class="data row2 col1" >34.973418</td>
#     </tr>
#     <tr>
#       <th id="T_fdff1_level0_row3" class="row_heading level0 row3" >Toluene</th>
#       <td id="T_fdff1_row3_col0" class="data row3 col0" >8041</td>
#       <td id="T_fdff1_row3_col1" class="data row3 col1" >27.229014</td>
#     </tr>
#     <tr>
#       <th id="T_fdff1_level0_row4" class="row_heading level0 row4" >Benzene</th>
#       <td id="T_fdff1_row4_col0" class="data row4 col0" >5623</td>
#       <td id="T_fdff1_row4_col1" class="data row4 col1" >19.041008</td>
#     </tr>
#     <tr>
#       <th id="T_fdff1_level0_row5" class="row_heading level0 row5" >AQI</th>
#       <td id="T_fdff1_row5_col0" class="data row5 col0" >4681</td>
#       <td id="T_fdff1_row5_col1" class="data row5 col1" >15.851139</td>
#     </tr>
#     <tr>
#       <th id="T_fdff1_level0_row6" class="row_heading level0 row6" >AQI_Bucket</th>
#       <td id="T_fdff1_row6_col0" class="data row6 col0" >4681</td>
#       <td id="T_fdff1_row6_col1" class="data row6 col1" >15.851139</td>
#     </tr>
#     <tr>
#       <th id="T_fdff1_level0_row7" class="row_heading level0 row7" >PM2.5</th>
#       <td id="T_fdff1_row7_col0" class="data row7 col0" >4598</td>
#       <td id="T_fdff1_row7_col1" class="data row7 col1" >15.570079</td>
#     </tr>
#     <tr>
#       <th id="T_fdff1_level0_row8" class="row_heading level0 row8" >NOx</th>
#       <td id="T_fdff1_row8_col0" class="data row8 col0" >4185</td>
#       <td id="T_fdff1_row8_col1" class="data row8 col1" >14.171549</td>
#     </tr>
#     <tr>
#       <th id="T_fdff1_level0_row9" class="row_heading level0 row9" >O3</th>
#       <td id="T_fdff1_row9_col0" class="data row9 col0" >4022</td>
#       <td id="T_fdff1_row9_col1" class="data row9 col1" >13.619586</td>
#     </tr>
#     <tr>
#       <th id="T_fdff1_level0_row10" class="row_heading level0 row10" >SO2</th>
#       <td id="T_fdff1_row10_col0" class="data row10 col0" >3854</td>
#       <td id="T_fdff1_row10_col1" class="data row10 col1" >13.050692</td>
#     </tr>
#     <tr>
#       <th id="T_fdff1_level0_row11" class="row_heading level0 row11" >NO2</th>
#       <td id="T_fdff1_row11_col0" class="data row11 col0" >3585</td>
#       <td id="T_fdff1_row11_col1" class="data row11 col1" >12.139785</td>
#     </tr>
#     <tr>
#       <th id="T_fdff1_level0_row12" class="row_heading level0 row12" >NO</th>
#       <td id="T_fdff1_row12_col0" class="data row12 col0" >3582</td>
#       <td id="T_fdff1_row12_col1" class="data row12 col1" >12.129626</td>
#     </tr>
#     <tr>
#       <th id="T_fdff1_level0_row13" class="row_heading level0 row13" >CO</th>
#       <td id="T_fdff1_row13_col0" class="data row13 col0" >2059</td>
#       <td id="T_fdff1_row13_col1" class="data row13 col1" >6.972334</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 1.6 Fix the data types for columns ( city & Date )

# %%
df['City'] = df['City'].astype('category')
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df.dtypes
# Out:
# City                category
# Date          datetime64[ns]
# PM2.5                float64
# PM10                 float64
# NO                   float64
# NO2                  float64
# NOx                  float64
# NH3                  float64
# CO                   float64
# SO2                  float64
# O3                   float64
# Benzene              float64
# Toluene              float64
# Xylene               float64
# AQI                  float64
# AQI_Bucket            object
# dtype: object

# %% [markdown]
# 1.7 remove duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(1418)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# 1.8 Save the cleaned version of the dataset to another folder in the google drive to ensure proper data management and to prevent re-reading or duplicating the raw files during future nuns. This also ensures the saved file is overwrite the previous one.

# %%
import os
os.makedirs(out_dir, exist_ok=True) #make sure the processed folder is created
output_files = os.path.join(out_dir, 'df_cleaned.csv') #define the output file path
df.to_csv(output_files, index=False)  #save the cleaned dataset
print("Cleaned Dataset saved successfully to" , output_files)
# Out:
# Cleaned Dataset saved successfully to /content/drive/MyDrive/Programming for Data Analysis/Assigment/processed/df_cleaned.csv
